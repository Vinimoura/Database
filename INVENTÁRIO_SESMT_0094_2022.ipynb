# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinimoura/Database/blob/main/INVENT%C3%81RIO_SESMT_0094_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade gspread
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
import pandas as pd 
import seaborn as sns
import numpy as np

# %%
tabela_inventario = gc.open_by_url('https://docs.google.com/spreadsheets/d/1lIT-ALP9uRcqmdHk14prWP7gOuBnDDKE1A73FMGhMZA/edit#gid=1868917484')

# %%
colaborativo = tabela_inventario.worksheet('inventario')

# %%
data_frame = pd.DataFrame(colaborativo.get_values())

# %%
#@title Default title text
pd.set_option("display.max_rows", None, "display.max_columns", None)
data_frame.style.render()
data_frame.head(215)
# Out:
#     0                                                 1   \
# 0
# 1
# 2       Assinale com "X" para Sim e com " - " para Não.
# 3
# 4                                                 Nº TAG
# 5                                              3742AFI01
# 6                                              3742LAV01
# 7
# 8                                              3745BTD01
# 9
# 10                                             3745CAM01
# 11
# 12                                             3742CRT01
# 13
# 14                                             3745CUB01
# 15
# 16
# 17
# 18                                             3742DTB02
# 19                                             3833ELE01
# 20
# 21                                             3701ELE01
# 22                                             3003ELE01
# 23
# 24                                             3745ELE02
# 25
# 26                                             3745ELE01
# ...

# %%
data_frame.tail()
# Out:
#     0          1                                    2   \
# 96      3742GIR01              EMBALAGEM LASANHA L1 L2
# 97      3742GIR02              EMBALAGEM LASANHA L1 L2
# 98
# 99
# 100                ENGENHEIRO DE SEGURANÇA DO TRABALHO
#
#                                                     3  4  5  6   \
# 96   TUNEL, TUNEL, MADEF, CILINDRICO, (GIROFREEZER L1)     X  X
# 97   TUNEL, TUNEL, MADEF, CILINDRICO, (GIROFREEZER L2)     X  X
# 98
# 99
# 100
#
#                              7  8  9  10 11 12 13 14 15
# 96                            X  X  X  X  X  -  2
# 97                            X  X  X  X  X  X  2
# 98
# 99
# 100  MANUTENÇÃO - RESP. TÉCNICO

# %%
receitas = fluxo_economico.worksheet('receitas')
data_frame = pd.DataFrame(receitas.get_all_records())
pd.set_option("display.max_rows", None, "display.max_columns", None)
data_frame.head()

# %%
extrato_lancamentos = fluxo_economico.worksheet('extrato_lancamentos')

# %%
data_frame = pd.DataFrame(extrato_lancamentos.get_all_records())

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
data_frame.columns

# %%
data_frame.shape

# %%
data_frame.describe()

# %%
#visualization
data_frame.head()

# %%
sns.relplot(x="Valor", y="Categoria", data=data_frame)

# %%
custos_discriminados = fluxo_economico.worksheet('custos_discriminados')
data_frame = pd.DataFrame(custos_discriminados.get_all_records())
pd.set_option("display.max_rows", None, "display.max_columns", None)
data_frame.head()

# %%
data_frame.columns

# %%
data_frame.shape

# %%
data_frame.describe()

# %%
#visualization
data_frame.head()

# %%
sns.relplot(x="Despesas Fixas", y="Categoria", data=data_frame)
